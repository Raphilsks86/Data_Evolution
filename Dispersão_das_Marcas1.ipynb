# %% [markdown]
# <a href="https://colab.research.google.com/github/Raphilsks86/Data_Evolution/blob/main/Dispers%C3%A3o_Clqs_Convrs_Marcas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Preparando os dados:

dados = pd.DataFrame({
    "Campanha" : ['Nike', 'Puma', 'Adidas', 'Reebok', 'New Balance'],
    "Cliques" : [320, 250, 300, 220, 280],
    "Conversões" : [40, 30, 35, 32, 34]
})

# %%
# Configurando o gráfico:

plt.figure(figsize = (14, 4))
sns.scatterplot(data = dados, x = "Cliques", y = "Conversões", hue = "Campanha", palette = "cool")
# Out:
# <Axes: xlabel='Cliques', ylabel='Conversões'>

# %%
# Criando uma grade de visualização:

plt.figure(figsize = (14, 4))
sns.scatterplot(data = dados, x = "Cliques", y = "Conversões", hue = "Campanha", palette = "cool", markers = {"Cliques" : "x", "Conversões" : "y"})

plt.title("Relação entre cliques e conversões por campanha")
plt.xlabel("Cliques")
plt.ylabel("Conversões")
plt.grid(True)
plt.show()
